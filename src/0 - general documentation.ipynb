# %% [markdown]
# <center>
#     <h1 id='demographic-filtering' style='color:#7159c1; font-size:350%'>General Documentation</h1>
#     <i style='font-size:125%'>Required knowledge and info about the project</i>
# </center>
#
# > **Topics**
#
# ```
# - 📝 Problem Description;
# - 📁 Datasets Descriptions;
# - ❓ Variables / Features;
# - 🌟 Target;
# - 📏 Metric;
# - 🛑 Limitations;
# - 🎯 Goals;
# - ⚙️ Setup;
# - 🎉 Acknowledgements.
# ```

# %% [markdown]
# <h1 id='0-problem-description' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>📝 | Problem Description</h1>
#
# Recommendation Systems are present everyday in our lives helping us to find the perfect anime to watch on Crunchyroll, to keep us binge watching related YouTube videos or even to buy new products on Amazon. I can spend the whole day listing examples about these systems, but I think that you got the glimpse where Recommendation Systems are used, don't you?
#
# However, have you ever get bored on Netflix and Instagram because they only recommend items related to the same topic? It is not because I liked two videos about cars on Instagram that I am a huge fan of cars and want to see only reels and posts about it. Or it is not because I saw a gamer chair price on Amazon that I want to buy only gamer chairs. When you keep receiving recommendations only related to a especific topic or product, we say that you are into a Limited Bubble of Recommendations.
#
# Limited Bubble of Recomendations tends to make companies lose customers, so, in order to minimize these bubbles and to expand the recommendations' diversity, algorithms have been tuned and new variables have been considered to the model.
#
# Nowadays, there are four main Recommendation Algorithms: `Demographic Filtering, Content-Based Filtering, Collaborative Filtering and Hybrid Filtering`, let's see how each one works assuming that we are dealing with Animes Recommendation.
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Demographic Filtering</p>
#
# > **Logic** - `it recommends animes that are popular between all users. Normally recommends the animes with higher Bayesian Mean Score, Arithmetic Mean Score and Popularity Rank`;
#
# > **Example** - `if Bleach, Oregairu and Jujutsu Kaisen are the animes with higher scores on a stream platform, this platform will recommend them to all users, regardless their tastes`;
#
# > **Metrics** - `Arithmetic Mean Score (when dealing with few ratings data), Bayesian Mean Score (when dealing with many ratings data) and Popularity Rank (when dealing with only popularity and not ratings)`;
#
# > **Advantages** - `1) only animes data is required; 2) the model training takes less time to compute; 3) the metric is not complicated to understand`;
#
# > **Disadvantages** - `1) bad recommendations are made since this technique generalizes the taste of all users to only one: the animes with higher Score and Popularity`.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/0-demographic-filtering.png' alt='Demographic Filtering Diagram' />
#     <figcaption>Figure 1 - Demographic Filtering Diagram. By <a href='https://www.width.ai/post/recommender-systems-recommendation-systems'>Matt Payne - Recommender Systems For Business - A Gentle Introduction©</a>.</figcaption>
# </figure>
#
# <br /><br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Content-Based Filtering</p>
#
# > **Logic** - `it recommends animes that are similar to other animes that a user liked. There are two variations of this technique: Plot Description Based (it recommends animes with similar synopsis) and Metadata Based (it recommends animes with similar metadata, such as genres, licensors, authors, producers and studios)`;
#
# > **Example** - `if a user liked Dragon Ball Z, there is a high probability that the platform will recommend Dragon Ball Super or Naruto (both shounen animes with superpowers)`;
#
# > **Metrics** - `Cosine Similarity Score, Jaccard Simiarity and Pearson Correlation. In this project, we will be working with Cosine Similarity Score`;
#
# > **Advantages** - `1) better recommendations are provided compared to Demographic Filtering Technique; 2) it recommends similar items that the users liked; 3) each user receives personalized recommendations`;
#
# > **Disadvantages** - `1) more data is required, such as items' synopsis and metadata; 2) when working on Plot Description Based Model, there is a probability to get only sequels and prequels recommendations; 3) when working on Metadata Based Model, there is a probability to create a Bubble that only recommends animes with a specific genre`.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/1-content-based-filtering.png' alt='Content-Based Filtering Diagram' />
#     <figcaption>Figure 2 - Content-Based Filtering Diagram. By <a href='https://medium.com/mlearning-ai/content-based-recommender-system-using-nlp-445ebb777c7a'>Arif Zainurrohman - Content-Based Recommender System Using NLP©</a>.</figcaption>
# </figure>
#
# <br /><br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Collaborative Filtering</p>
#
# > **Logic** - `it recommends animes that are similar to animes liked by similar users. There are two variations of this technique: User Based Filtering (when dealing with users similarity) and Item Based Filtering (when dealing with items similarity). Both of them follow the Memory/Neighborhood Logic`;
#
# > **Example** - `if user A and user B liked Demon Slayer, user A is considered similar to user B. If user B also liked Grand Blue, the platform will recommend Grand Blue to user A`;
#
# > **Metrics** - `Cosine Similarity Score, Jaccard Similarity and Pearson Correlation. In this project, we will be working with Cosine Similarity Score`;
#
# > **Advantages** - `1) better recommendations are provided compared to Content-Based and Demographic Filtering; 2) it recommends similar items that similar users liked; 3) each user receives personalized recommendations; 4) there is a few probability to create a Bubble of Contents`;
#
# > **Disadvantages** - `1) anime and user data are required; 2) the dataset must contain a significant amount of user ratings to animes; 3) there is yet a probability of creating a Bubble of Contents; 4) it is needed to add a cut-off amount of ratings and mean rating score by user in order to avoid outliers; 5) the algorithm is more complex and takes more time to run`.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/2-collaborative-filtering.png' alt='Collaborative Filtering Diagram' />
#     <figcaption>Figure 3 - Collaborative Filtering Diagram. By <a href='https://www.analyticsvidhya.com/blog/2022/02/introduction-to-collaborative-filtering/'>Shivam Baldha - Introduction to Collaborative Filtering©</a>.</figcaption>
# </figure>
#
# <br /><br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Hybrid Filtering</p>
#
# > **Logic** - `it combines the Content-Based and Collaborative Filtering techniques. It normally applies the first one when there are few users ratings available and smoothly replaces it to the second one as more users ratings become available`;
#
# > **Example** - `1) When few users ratings are availabe: if a user liked Dragon Ball Z, there is a high probability that the platform will recommend Dragon Ball Super or Naruto (both shounen animes with superpowers); 2) When many users ratings are available: if user A and user B liked Demon Slayer, user A is considered similar to user B and user B also liked Grand Blue, the platform will recommend Grand Blue to user A`;
#
# > **Metrics** - `Receiving Operation Characteristic [ROC] Curve and Root Mean Squared Error [RMSE]`;
#
# > **Advantages** - `1) since it combines two techniques, it contains the advantages related to both of them; 2) also, it decreases the probability of making poor recommendations when the platform is new and does not contain many users ratings`;
#
# > **Disadvantages** - `1) since it combines two techniques, it contains the disadvantages related to both of them; 2) also, it requires more computational resources since the algorithm is more complex and complete than the previous ones`.
#
# ---

# %% [markdown]
# <h1 id='1-datasets-descriptions' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>📁 | Datasets Descriptions</h1>
#
# > **anime-dataset-2023.csv** - `data about animes available in MyAnimeList website, such as name, genres and mean score. It contains 24 variables and 24,905 observations;`
#
# > **users-details-2023.csv** - `data about MyAnimeList users, as username, gender and number of watched animes. It contains 16 variables and 731,290 observations;`
#
# > **users-score-2023.csv** - `data about scores provided by users to animes. It contains 5 variables and 24,325,191 observations.`
#
# ---

# %% [markdown]
# <h1 id='2-variables-features' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>❓ | Variables / Features</h1>
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- anime-dataset-2023.csv</p>
#
# > **Anime ID** - `anime id on MyAnimeList`;
#
# > **Name** - `anime original name`;
#
# > **English Name** - `English version name`;
#
# > **Other Name** - `Japanese version name`;
#
# > **Score** - `weighted/Bayesian average score`. You can check out for more details at ["How are MyAnimeList scores calculated?"](https://myanimelist.net/info.php?go=topanime);
#
# > **Genres** - `related genres`;
#
# > **Synopsis** - `briefly description`;
#
# > **Type** - `type of animation (movie, anime, OVA...)`;
#
# > **Episodes** - `number of episodes. Movies are considered having 1 episode`;
#
# > **Aired** - `period when anime was aired`;
#
# > **Premiered** - `season when the anime was released`;
#
# > **Status** - `current status (airing, hiatus, finished...)`;
#
# > **Producers** - `related production companies`;
#
# > **Licensors** - `related streaming platforms and licensors`;
#
# > **Studios** - `related animation studios`;
#
# > **Source** - `source material of the anime (originated from manga, light novel, movie or tv)`;
#
# > **Duration** - `duration of the movie or each episode`;
#
# > **Rating** - `age restriction`;
#
# > **Rank** - `rank position on MyAnimeList website (based on Score criteria)`;
#
# > **Popularity** - `popularity position on MyAnimeList`;
#
# > **Favorites** - `number of users that marked the anime as favorite`;
#
# > **Scored By** - `number of users that rated the anime`;
#
# > **Members** - `number of users that added the anime to the watch list`;
#
# > **Image Url** - `banner url`.
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- users-details-2023.csv</p>
#
# > **Mal ID** - `user id`;
#
# > **Username** - `nickname`;
#
# > **Gender** - `user gender`;
#
# > **Birthday** - `birthday`;
#
# > **Location** - `user's location or country`;
#
# > **Joined** - `the joined date on MyAnimeList Platform (ISO format)`;
#
# > **Days Watched** - `total number of days the user spent on MyAnimeList`;
#
# > **Mean Score** - `the average score the user gives to the watched animes`;
#
# > **Watching** - `number of animes currently being watched by the user`;
#
# > **Completed** - `number of animes finished by the user`;
#
# > **On Hold** - `number of animes that the user stopped watching but kept it into its list`;
#
# > **Dropped** - `number of animes that the user stopped watching and removed from its list`;
#
# > **Plan to Watch** - `number of animes that the user has added into the list but did not started watching`;
#
# > **Total Entries** - `total number of animes into the user's list`;
#
# > **Rewatched** - `number of animes rewatched`;
#
# > **Episodes Watched** - `number of episodes watched from all animes`.
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- users-score-2023.csv</p>
#
# > **User ID** - `user id on MyAnimeList Platform`;
#
# > **Username** - `nickname`;
#
# > **Anime ID** - `anime id on MyAnimeList Platform`;
#
# > **Anime Title** - `anime original name`;
#
# > **Rating** - `score that the user rated the anime`.
#
# ---

# %% [markdown]
# <h1 id='3-target' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>🌟 | Target</h1>
#
# > **Demographic Filtering** - `animes Weighted/Bayesian Mean Score and Popularity`;
#
# > **Content-Based Filtering** - `Cosine Similarity between the animes`;
#
# > **Collaborative Filtering** - `Cosine Similarity between the users`;
#
# > **Hybrid Filtering** - `similarity between the users validated with ROC Curve and predicted users ratings validated with RMSE`.
#
# ---

# %% [markdown]
# <h1 id='4-metrics' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>📏 | Metrics</h1>
#
# Four metrics were used to evaluate the Models: `Bayesian Mean` for Demographic Filtering, `Cosine Similarity` for Content-Based and Collaborative Filtering, `ROC Curve` and `Root Mean Squared Error [RMSE]` for Hybrid Filtering.
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Bayesian Mean</p>
#
# When working with mean scores of products, we have a tendency to use the `Arithmetic Mean` rather than other metrics, however, it can be a problem for Recommendation System Models due to the difference between the score value and the amount of scores. For instance, picture an anime that has a Mean Score of 9.8 and only 100 votes, and another anime with a Mean Score of 8.5 and 100,000 votes. Which one is better? The one with the higher score and less votes or the one with the smaller score and more votes? In this case and statistically speaking, it is correct to assume that the one with the smaller score and more votes is the better because the difference of the amount of votes between the two animes is huge. So, we have just stumbled upon a problem: there are situations that the Arithmetic Mean is not suitable and can compromisse Recommendation Systems Models.
#
# Having this in mind, we can use the `Cumulative Mean`. Its idea is similar to the Arithmetic one, but the difference is that the value is not divided by the number of votes. So, if an anime got two ratings of 10, we say that its Cumulative Mean is 20, while its Arithmetic Mean is 10. But, this method has a problem too: consider an anime with 1,000,000 ratings of 1 score and another anime with 10,000 ratings of 10 score, if we calculate their Cumulative Mean, the first anime will have a score of 1,000,000 whereas the second one will have a score of 100,000. So, even though having the better ratings, the anime can be in a bad rank position if the number of votes is substancial lower than an anime with worse ratings and a huge number of votes.
#
# So, up to now, we have this two metrics problems:
#
# > **Arithmetic Mean** - `does not assume that an anime with lower score and huge number of ratings is better than an anime with higher score and only a few number of ratings`;
#
# > **Cumulative Mean** - `does not assume that an anime with a lower score and huge number of good ratings is better than an anime with higher score and a more huge number of bad ratings`.
#
# <br /><br />
#
# In order to solve these two problems and to giver better, realistic mean scores, the `Bayesian Mean` has been created!! Its idea is simple, first we have to find the number of ratings of the item, the Arithmetic Mean of the item, the minimum number of ratings that an item must have to be considered in the system and the Arithmetic Mean across all items. After that, we apply them in the following equation:
#
# ```python
# bayeasian_mean = ((v / (v + m)) * A) + ((m / (v + m)) * C)
# ```
#
# $$
# Bayesian Mean = \frac{v}{v + m} \cdot A + \frac{m}{v + m} \cdot C
# $$
#
# where:
#
# - v: number of the item's ratings;
# - m: minimum number of ratings that an item must have to be considered in the system;
# - A: item's Arithmetic Man;
# - C: Arithmetic Mean across all items.
#
# <br />
#
# The equation can also be used in its alternative form, resulting in the same result:
#
# ```python
# bayesian_mean = ((c * m) + (n * r)) / (c + n)
# ```
#
# $$
# Bayesian Mean = \frac{(c \cdot m) + (n \cdot r)}{(c + n)}
# $$
#
# where:
#
# - c: minimum number of ratings that an item must have to be considered in the system;
# - m: Arithmetic Mean across all items;
# - n: number of the item's ratings;
# - r: item's Arithmetic Mean.
#
# <br />
#
# Due to its good results, Bayesian Mean is used by IMDB to calculate the mean score of movies listed on the website.
#
# Also, it is highly recommended to start using Arithmetic Mean when there are a few ratings to an item and smoothly migrate to Bayesian Mean accordingly the number of ratings increase.
#
# Some observations about this metric:
#
# - for an item with a fewer than average number of ratings - the score should be around the system’s Arithmetic Mean;
# - for an item with a substantial number of ratings - the score should be the item’s Arithmetic Mean;
# - as the number of ratings that an item receives increases, the score should gradually move from system’s Mean to item’s Mean.
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Cosine Similarity</p>
#
# `Cosine Similarity` is a perfect metric to measure the similarity between two values of a same feature, especially when dealing with sequential texts or rating scores. In a nutshell, it works dividing the sum of the multiplication of the appearance of the elements in each items by the product of the squared root of the quadratic appearance of each element into the items 🤯😶‍🌫️. You can be wondering: *What the hell did I just read?*. Do not worry, The example below makes everything clear 🤣
#
# Consider these two sentences: `Hello World!` (sentence A) and `Hello!` (sentence B). The first thing to do is to create a table showing the frequency of each word in each sentence:
#
# <table style='border-style: solid'>
#     <caption>Frequency Table of Each Word in Each Sentence</caption>
#     <tr align='center' style='border-style: solid'>
#         <th style='border-style: solid'>Word</th>
#         <th style='border-style: solid'># in A</th>
#         <th style='border-style: solid'># in B</th>
#     </tr>
#     <tr align='center'>
#         <td style='border-style: solid'><b>Hello</b></td>
#         <td style='border-style: solid'>1</td>
#         <td style='border-style: solid'>1</td>
#     </tr>
#     <tr align='center'>
#         <td style='border-style: solid'><b>World</b></td>
#         <td style='border-style: solid'>1</td>
#         <td style='border-style: solid'>0</td>
#     </tr>
# </table>
#
# After that, we:
#
# - plot the frequencies using points;
# - trace two lines across the points, one line to one point;
# - calculate the angle between the lines;
# - calculate the cosine of the angle;
# - the cosine of the angle is the Cosine Similarity Score. It goes from 0 (completely not similar) to 1 (completely similar).
#
# In this example, the angle between the lines is `45º` and its cosine is `0.71`, thus we can tell that both sentences are 71% similar. The image below ilustrates the plot and the calculation:
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/3-cosine-similarity-statquest.png' alt='Cosine Similarity of the Example' />
#     <figcaption style='text-align: center'>Figure 4 - Cosine Similarity calculation of sentences in the example. By <a href='https://www.youtube.com/watch?v=e9U0QAFbfLI'>StatQuest with Josh Starmer - Cosine Similarity, Clearly Explained!!!©</a>, at 03:34 minutes.</figcaption>
# </figure>
#
# <br /><br />
#
# Quite simple and easy to catch, isn't it? You can check out a better explanation about this topic accessing the StatQuest YouTube video anexed on Acknowledgements Section.
#
# Just one more thing, the frequency does not have influence in the similarity, only the presence or not presence have influence. It means that the sentences `Hello!` and `Hello! Hello! Hello!` have the same Cosine Similarity to `Hello World!`, since the angle between the lines is still 45º. The image below ilustrates it:
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/4-cosine-similarity-statquest.png' alt='Cosine Similarity of the Example' />
#     <figcaption style='text-align: center'>Figure 5 - Cosine Similarity calculation of the new example. By <a href='https://www.youtube.com/watch?v=e9U0QAFbfLI'>StatQuest with Josh Starmer - Cosine Similarity, Clearly Explained!!!©</a>, at 04:24 minutes.</figcaption>
# </figure>
#
# <br /><br />
#
# Now that we already know how it works, let's take a peek at its equation:
#
# ```python
# sum(Wq[k] * Wd[k]) / (sqrt(sum(Wq[k]**2)) * sqrt(sum(Wd[k]**2)))
# ```
#
# $$
# Cosine Similarity = \frac{\sum_{k=1}^{t} (Wq[k] \cdot Wd[k])} {\sqrt{\sum_{k=1}^{t} (Wq[k]^2)} \cdot \sqrt{\sum_{k=1}^{t} (Wd[k]^2)}}
# $$
#
# where:
#
# - Wq and Wd: items;
# - k: each word present into the Bag of Words;
# - t: amount of words into the Bag of Words;
# - Wq[k] and Wd[k]: frequence of 'k' word into 'Wq' and 'Wd' items.
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- ROC Curve</p>
#
# ```
# [TO-DO]
# ```
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- Root Mean Squared Error [RMSE]</p>
#
# ```
# [TO-DO]
# ```
#
# ---

# %% [markdown]
# <h1 id='5-limitations' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>🛑 | Limitations</h1>
#
# Since the data were extracted only from MyAnimeList, the Recommendation Models only make recommendations based on animes and users' ratings present in MyAnimeList website, excluding other streams, such as Crunchyroll, Netflix and Funimation.
#
# Also, the datasets contain observations up to October 6th, 2023. So all released animes and all users' ratings provided after this date do not have influence in the models.
#
# In the end, since all data are related to animes, the Models are limited to this kind of content.
#
# ---

# %% [markdown]
# <h1 id='6-goals' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>🎯 | Goals</h1>
#
# > **Goal 1** - `study and understand each variable present into the datasets`;
#
# > **Goal 2** - `clear and apply feature engineering`;
#
# > **Goal 3** - `create different Recommender Models using Demographic Filtering, Content-Based Filtering, Collaborative Filtering and Hybrid Filtering Techniques`;
#
# > **Goal 4** - `measure and compare the models by performance (CPU and RAM usages) and by computation time cost. As well, compare the resulted recommendations of each model.`
#
# ---

# %% [markdown]
# <h1 id='7-Setup' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>⚙️ | Setup</h1>
#
# > **Tools**
#
# - Python 3.10.x Version or later;
#
# - Jupyter Lab 3.5.x Version or later;
#
# - Jupyter Notebook 3.5.x Version or later;
#
# - Microsoft C++ Built Tools 14.x Version or later (only for Windows OS). Tutorial about how to install the build tools can be find in this [Stack Overflow Post](https://stackoverflow.com/questions/44951456/pip-error-microsoft-visual-c-14-0-is-required).
#
# <br />
#
# > **Packages**
#
# - Numpy, Pandas, Matplotlib, MPL Cyberpunk, Seaborn and Collections;
#
# ```bash
# pip install numpy pandas matplotlib mplcyberpunk seaborn collections
# ```
#
# <br />
#
# - Chardet, Re, Math and string;
#
# ```bash
# pip install chardet re math string
# ```
#
# <br />
#
# - Sklearn, Surprise and LightFM;
#
# ```bash
# pip install sklearn
# pip install scikit-surprise
# pip install lightfm
# ```
# <br />
#
# - SpaCy.
#
# ```bash
# pip install -U pip setuptools wheel
# pip install -U spacy
# python -m spacy download en_core_web_sm >> efficiency (English Model)
# python -m spacy download en_core_web_trf >> accuracy (English Model)
# ```

# %% [markdown]
# <h1 id='8-Acknowledgements' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>🎉 | Aknowledgements</h1>
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- 📖 Bibliographic References</p>
#
# > 1. Burke, R. 2002. [Hybrid recommender systems: Survey and experiments](https://fcd.ugr.es/sites/centros/fcd/public/ficheros/PROYECTO2023/Burke2002_Article_HybridRecommenderSystemsSurvey.pdf). Journal User Modeling and User-Adapted Interaction 12: 331-370. Last Access: March 20, 2024.
#
# > 2. Chomboon, K.; Chujai, P.; Teerarassamee, P.; Kerdprasop, K.; Kerdprasop, N. 2015. [An Empirical Study of Distance Metrics for k-Nearest Neighbor Algorithm](https://pdfs.semanticscholar.org/815f/22363962afda432435cdbb478857547a17b5.pdf). In: Institute of Industrial Applications Engineers, 2015, Kitakyushu, Fukuoka, Japan. Proceedings... p. 280-285. Last Access: March 15, 2024.
#
# > 3. Das, A.; Datar, M.; Garg, A.; Rajaram, S. 2007. [Google News Personalization: Scalable Online Collaborative Filtering](https://www.ri.cmu.edu/pub_files/2009/0/p271-das.pdf). In: WWW 2007 / Track: Industrial Practice and Experience, 2007, Banff, Alberta, Canadá. Proceedings... p. 271-280. Last Access: March 20, 2024.
#
# > 4. Khatri, A. 2017. [Popularity based product rating system using Bayesian model](https://dspace.library.uvic.ca/server/api/core/bitstreams/c615f973-11b4-417c-b196-7b4d94bd55b8/content). Computer Engineering Master's Degree. University of Victoria, Victoria, British Columbia, Canada. Last Access: March 15, 2024.
#
# > 5. Rahutomo, F.; Kitasuka, T.; Aritsugi, M. 2012. [Semantic Cosine Similarity](https://www.researchgate.net/profile/Faisal-Rahutomo/publication/262525676_Semantic_Cosine_Similarity/links/0a85e537ee3b675c1e000000/Semantic-Cosine-Similarity.pdf). In: The 7th International Student Conference on Advanced Science and Technology ICAST, 2012, Seul, South Korea. Proceedings... p. 1-2. Last Access: March 15, 2024.
#
# > 6. Ricci, F.; Rokach, L.; Shapira, B.; Kantor, P.B. 2011. [Recommender Systems Handbook](https://d1wqtxts1xzle7.cloudfront.net/32978074/Recommender_systems_handbook.pdf). 1ed. Springer, New York, NY, USA. Last Access: March 20, 2024.
#
# > 7. Silva, R.G.N. e. 2014. [Sistema de Recomendação baseado em conteúdo textual: avaliação e comparação](https://repositorio.ufba.br/bitstream/ri/19281/1/dissertacao_mestrado_ciencia_computacao_rafael_glauber.pdf). Computer Science Multi-Institutional Master's Degree MMCC. Universidade Federal da Bahia e Universidade Estadual de Feira de Santana, Salvador, Bahia, Brazil. Last Access: March 20, 2024.
#
# > 8. Whittaker, S.; Sidner, C. 1996. [Email overload: exploring personal information management of email](https://dl.acm.org/doi/pdf/10.1145/238386.238530). In: CHI – Conference on Human Factors in Computing Systems, 1996, Vancouver, British Columbia, Canada. Proceedings... p. 276-283. Last Access: March 20, 2024.
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- 📃 General Documentation</p>
#
# > 1. Demographic Filtering Diagram image provided by [Matt Payne - Recommender Systems For Business - A Gentle Introduction](https://www.width.ai/post/recommender-systems-recommendation-systems);
#
# > 2. Content-Based Filtering Diagram image provided by [Arif Zainurrohman - Content-Based Recommender System Using NLP](https://medium.com/mlearning-ai/content-based-recommender-system-using-nlp-445ebb777c7a);
#
# > 3. Collaborative Filtering Diagram image provided by [Shivam Baldha - Introduction to Collaborative Filtering](https://www.analyticsvidhya.com/blog/2022/02/introduction-to-collaborative-filtering/);
#
# > 4. Data extracted from [MyAnimeList](https://myanimelist.net) website;
#
# > 5. Data extracted using [Jikan API](https://jikan.moe);
#
# > 6. Scrapper created by the author of this notebook. The source code is present in [anime-data-scrapper](https://github.com/CSFelix/anime-data-scrapper) GitHub Repository;
#
# > 7. Dataset provided by [Sajid](https://www.kaggle.com/dbdmobile): ["Anime Dataset 2023"](https://www.kaggle.com/datasets/dbdmobile/myanimelist-dataset);
#
# > 8. Introduction to Movie Recommendation System by [Ibtesam Ahmed](https://www.kaggle.com/ibtesama): ["Getting Started with a Movie Recommendation System"](https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system);
#
# > 9. Discussion about Arithmetic Mean, Cumulative Mean and Bayesian Mean by [Arpit Bhayani](https://arpitbhayani.me): ["Do not just rank your results by average rating, use Bayesian Average instead"](https://arpitbhayani.me/blogs/bayesian-average/);
#
# > 10. Explanation about Cosine Similarity by [StatQuest with Josh Starmer](https://www.youtube.com/@statquest): ["Cosine Similarity, Clearly Explained!!!"](https://www.youtube.com/watch?v=e9U0QAFbfLI).
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- 🧼 Data Wrangling and Fature Engineering</p>
#
# > ...
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- ✨ Demographic Filtering</p>
#
# > 1. Explanation about Arithmetic Mean, Cumulative Mean and Bayesian Mean by [Arpit Bhayani](https://arpitbhayani.me): [Do not just rank your results by average rating, use Bayesian Average instead](https://arpitbhayani.me/blogs/bayesian-average/);
#
# > 2. Explanation about Recommendation Systems by [Francesco Casalegno](https://medium.com/@francesco.casalegno): [Recommender Systems — A Complete Guide to Machine Learning Models](https://towardsdatascience.com/recommender-systems-a-complete-guide-to-machine-learning-models-96d3f94ea748);
#
# > 3. Movie Recommendation Systems with Python by [Ibtesam Ahmed](https://www.kaggle.com/ibtesama): [Getting Started with a Movie Recommendation System](https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system);
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- ✨ Content-Based Filtering by Plot Description and Content-Based Filtering by Metadatas</p>
#
#
# > 1. Explanation about Cosine Similarity by [StatQuest with Josh Starmer ](https://www.youtube.com/@statquest): [The Cosine Similarity for NLP and CatBoost](https://www.youtube.com/watch?v=c3xEDTh7Uc8);
#
# > 2. Explanation about Linear Kernel Trick by [Visually Explained](https://www.youtube.com/@VisuallyExplained): [The Kernel Trick in Support Vector Machine (SVM)](https://www.youtube.com/watch?v=Q7vT0--5VII);
#
# > 3. Explanation about Part-of-speech tagging by [DataCamp](https://www.datacamp.com): [Part-of-speech tagging](https://campus.datacamp.com/courses/feature-engineering-for-nlp-in-python/text-preprocessing-pos-tagging-and-ner?ex=8);
#
# > 4. Explanation about Stemming and Lemmatization in Python by [Kurtis Pykes](https://www.datacamp.com/portfolio/kurtispykes): [Stemming and Lemmatization in Python](https://www.datacamp.com/tutorial/stemming-lemmatization-python);
#
# > 5. Explanation about TF-IDF by [Data Science Garage](https://www.youtube.com/@DataScienceGarage): [Calculate TF-IDF in NLP (Simple Example)](https://www.youtube.com/watch?v=vZAXpvHhQow);
#
# > 6. Explanation and application of Content-Based Recommendation System by [Yannawut Kimnaruk](https://medium.com/@yannawut): [Basic content-based recommendation system with Python code](https://medium.com/mlearning-ai/basic-content-based-recommendation-system-with-python-code-be920b412067);
#
# > 7. Explanation and usage of TF-IDF Vectorizer by [Mukesh Chaudhary](https://medium.com/@cmukesh8688): [TF-IDF Vectorizer scikit-learn](https://medium.com/@cmukesh8688/tf-idf-vectorizer-scikit-learn-dbc0244a911a);
#
# > 8. Movie Recommendation Systems with Python by [Ibtesam Ahmed](https://www.kaggle.com/ibtesama): [Getting Started with a Movie Recommendation System](https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system).
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- ✨ Collaborative Filtering by User-Based and Collaborative Filtering by Item-Based</p>
#
# > 1. Explanation about differences between KNN and K-Means by [Oscar Alsing Ferreira](https://www.youtube.com/@OscarAlsing): [What Is The Difference Between KNN and K-means?](https://www.youtube.com/watch?v=OClrEI_5Ri4);
#
# > 2. Explanation about K-Means Clustering by [StatQuest with Josh Starmer](https://www.youtube.com/@statquest): [StatQuest: K-means clustering](https://www.youtube.com/watch?v=4b5d3muPQmA)
#
# > 3. Explanation about K-Nearest Neighbor by [StatQuest with Josh Starmer](https://www.youtube.com/@statquest): [StatQuest: K-nearest neighbors, Clearly Explained](https://www.youtube.com/watch?v=HVXime0nQeI);
#
# > 4. Explanation about Matrices by [Visual Kernel](https://www.youtube.com/@visualkernel): [Visualize Different Matrices part1 | SEE Matrix, Chapter 1](https://www.youtube.com/watch?v=7Gtxd-ew4lk&list=PLWhu9osGd2dB9uMG5gKBARmk73oHUUQZS&index=1) and [Visualize Different Matrices part2 | SEE Matrix, Chapter 1](https://www.youtube.com/watch?v=wciU07gPqUE&list=PLWhu9osGd2dB9uMG5gKBARmk73oHUUQZS&index=2);
#
# > 5. Explanation about Matrix Singular Value Decomposition (SVD) by [Visual Kernel](https://www.youtube.com/@visualkernel): [SVD Visualized, Singular Value Decomposition explained | SEE Matrix , Chapter 3 #SoME2](https://www.youtube.com/watch?v=vSczTbgc8Rc&list=PLWhu9osGd2dB9uMG5gKBARmk73oHUUQZS&index=4);
#
# > 6. Explanation about Matrix Spectral Decomposition by [Visual Kernel](https://www.youtube.com/@visualkernel): [Visualize Spectral Decomposition | SEE Matrix, Chapter 2](https://www.youtube.com/watch?v=mhy-ZKSARxI&list=PLWhu9osGd2dB9uMG5gKBARmk73oHUUQZS&index=3);
#
# > 7. Explanation about Singular Value Decomposition (SVD) by [Simon Funk](https://sifter.org/~simon/): [Netflix Update: Try This at Home](https://sifter.org/~simon/journal/20061211.html);
#
# > 8. Explanation about Singular Value Decomposition Plus (SVD++) by [Yehuda Korean](yehuda@research.att.com): [Factorization Meets the Neighborhood: a Multifaceted Collaborative Filtering Model](https://people.engr.tamu.edu/huangrh/Spring16/papers_course/matrix_factorization.pdf)
#
# > 9. Introduction to Collaborative Filtering System by [Rangarajan Saranathan](https://www.kaggle.com/rangarajansaranathan): ["Collaborative Filtering Based Recommender System"](https://www.kaggle.com/code/rangarajansaranathan/collaborative-filtering-based-recommender-system);
#
# > 10. Introduction to Movie Recommendation System by [Ibtesam Ahmed](https://www.kaggle.com/ibtesama): ["Getting Started with a Movie Recommendation System"](https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system);
#
# > 11. Surprise Python Package Documentation: [Welcome to Surprise’ documentation!](https://surprise.readthedocs.io/en/stable/).
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- ✨ Hybrid Filtering</p>
#
# > 1. Explanation about how LightFM works by [miguelgfierro](https://github.com/miguelgfierro): [LightFM - hybrid matrix factorisation on MovieLens (Python, CPU)](https://github.com/recommenders-team/recommenders/blob/main/examples/02_model_hybrid/lightfm_deep_dive.ipynb);
#
# > 2. LightFM Documentation: [Welcome to LightFM’s documentation!](https://making.lyst.com/lightfm/docs/home.html);
#
# > 3. LightFM GitHub Repository: [lightfm](https://github.com/lyst/lightfm).
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- 🎗️ Comparing the Models</p>
#
# > ...
#
# <br />
#
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>- ⛏️ API Scrapper</p>
#
# > 1. Jikan - Unofficial MyAnimeList API. It is present in [jikan.moe](https://jikan.moe) website;
#
# > 2. Jikan REST API v4 Docs. Documentation is present in [Information Section](https://docs.api.jikan.moe/#section/Information) website;
#
# > 3. MyAnimeList present at [MyAnimeList.net](https://myanimelist.net) website;

# %% [markdown]
# ---
#
# <h1 id='reach-me' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>📫 | Reach Me</h1>
#
# > **Email** - [csfelix08@gmail.com](mailto:csfelix08@gmail.com?)
#
# > **Linkedin** - [linkedin.com/in/csfelix/](https://www.linkedin.com/in/csfelix/)
#
# > **GitHub:** - [CSFelix](https://github.com/CSFelix)
#
# > **Kaggle** - [DSFelix](https://www.kaggle.com/dsfelix)
#
# > **Portfolio** - [CSFelix.io](https://csfelix.github.io/).
